# %%
# %load_ext ferretmagic

# %%
# %%ferret
# can mode logo
# set text/font=Arial
# se da eez.nc
# fill/title=EEZs/pal=rnb2 eez
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
#Checking which EEZs are along the Atlantic South American coast

# %%
# %%ferret -s 600,1000
# shade/title=EEZs/pal=rnb2/xlim=70W:25W/ylim=-90:20 eez[d=1]
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
#Test whether any are missing with the map above and list below

# %%
# %%ferret
# li eez[x=70W:55W,y=8N:20N]
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">             VARIABLE : SCAT2GRID_BIN_XY(V1[D=3],V2[D=3],V3[D=3],X[GX=SPEED[D=1]],Y[GY=SPEED[D=1]])
#              FILENAME : eez.nc
#              SUBSET   : 30 by 24 points (LONGITUDE-LATITUDE)
#       ... listing every   2th point
#                 69.75W 68.75W 67.75W 66.75W 65.75W 64.75W 63.75W 62.75W 61.75W 60.75W 59.75W 58.75W 57.75W 56.75W 55.75W
#                 581    583    585    587    589    591    593    595    597    599    601    603    605    607    609
#  19.75N / 191:   92.0   92.0   92.0   93.0   93.0   94.0   94.0   95.0   95.0   97.0   97.0   -1.0   -1.0   -1.0   -1.0
#  19.25N / 190:    0.0   92.0   92.0   93.0   93.0   94.0   94.0   95.0   95.0   97.0   97.0   97.0   -1.0   -1.0   -1.0
#  18.75N / 189:    0.0    0.0   93.0   93.0   93.0   94.0   95.0   95.0   97.0   97.0   97.0   97.0   -1.0   -1.0   -1.0
# ...

# %%
#Checking which EEZs surround the Arkona-Bornholm basin

# %%
# %%ferret -s 600,600
# shade/title=EEZs/pal=rnb2/xlim=10:20/ylim=50:60/graticule eez[d=1]; go land
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">! Enter_GO land
# ! Exit_GO
# </pre>
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# li eez[x=13.25E:15.75E,y=54N:56N]
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">             VARIABLE : SCAT2GRID_BIN_XY(V1[D=3],V2[D=3],V3[D=3],X[GX=SPEED[D=1]],Y[GY=SPEED[D=1]])
#              FILENAME : eez.nc
#              SUBSET   : 6 by 4 points (LONGITUDE-LATITUDE)
#                 13.25E 13.75E 14.25E 14.75E 15.25E 15.75E
#                  27     28     29     30     31     32
#  55.75N / 263:    0.0    0.0  226.0  226.0  226.0  226.0
#  55.25N / 262:  226.0  226.0  226.0    0.0  136.0  136.0
#  54.75N / 261:  227.0  227.0  227.0  136.0  202.0  202.0
#  54.25N / 260:    0.0  227.0  227.0  202.0  202.0  202.0
# </pre>

# %%
# %%ferret
# go make_shapefiles_jun23
# Out:
#  LISTing to file sa_cont_shelf-1414.nc
#  LISTing to file ab_deeps-393.nc
# rm: ferret.j*: No such file or directory
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">! Enter_GO make_shapefiles_jun23
# ! Exit_GO
# </pre>

# %%
# %%ferret -s 600,800
# shade/title="Atlantic South American Continental Shelf"/pal=blue_darkred/xlim=90W:20W/ylim=60S:20N sa_cont_shelf; go land
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">! Enter_GO land
# ! Exit_GO
# </pre>
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# shade/title="Arkona-Bornholm Deeps Below 40 m"/pal=blue_darkred/xlim=0E:60E/ylim=40N:80N ab_deeps; go land
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">! Enter_GO land
# ! Exit_GO
# </pre>
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
#Run the global version:

# %%
# %%ferret
# go make_global_shapefiles
# Out:
#  LISTing to file cont_shelf.nc
#  LISTing to file cont_slope.nc
# rm: ferret.j*: No such file or directory
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">! Enter_GO make_global_shapefiles
# ! Exit_GO
# </pre>

# %%
# %%ferret
# shade/title="Global Continental Shelves" cont_shelf; go land
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">! Enter_GO land
# ! Exit_GO
# </pre>
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# shade/title="Global Continental Slopes" cont_slope; go land
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">! Enter_GO land
# ! Exit_GO
# </pre>
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>
